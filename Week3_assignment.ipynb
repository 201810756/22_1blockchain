# %% [markdown]
# # 휴먼지능정보공학과 201810756 김대환
# ## 블록체인프로그래밍 3주차 과제
# ----

# %% [markdown]
# ### [1번 문제 : 현재 블록번호를 출력]
# ----
# ![1%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%B3%E1%86%AF%E1%84%85%E1%85%A9%E1%86%A8%E1%84%87%E1%85%A5%E1%86%AB%E1%84%92%E1%85%A9.png](attachment:1%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%B3%E1%86%AF%E1%84%85%E1%85%A9%E1%86%A8%E1%84%87%E1%85%A5%E1%86%AB%E1%84%92%E1%85%A9.png)
#
# -----

# %% [markdown]
# ### [2번 문제 : enode 값 출력]
# ----
# ![2%E1%84%87%E1%85%A5%E1%86%AB_enode.png](attachment:2%E1%84%87%E1%85%A5%E1%86%AB_enode.png)
#
# ---

# %% [markdown]
# ### [3번 문제 : peer]
# ---
# ![3%E1%84%87%E1%85%A5%E1%86%AB_peer.png](attachment:3%E1%84%87%E1%85%A5%E1%86%AB_peer.png)
#
# ---

# %% [markdown]
# ### [4번 문제 : 계정 목록]
# ----
# ![4%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%80%E1%85%A8%E1%84%8C%E1%85%A5%E1%86%BC%E1%84%86%E1%85%A9%E1%86%A8%E1%84%85%E1%85%A9%E1%86%A8.png](attachment:4%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%80%E1%85%A8%E1%84%8C%E1%85%A5%E1%86%BC%E1%84%86%E1%85%A9%E1%86%A8%E1%84%85%E1%85%A9%E1%86%A8.png)
# * 현재 계정 5개
# ----

# %% [markdown]
# ### [5번 문제 : 각 계정의 잔액(Ether) 출력]
# ---
# ![5%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%8C%E1%85%A1%E1%86%AB%E1%84%8B%E1%85%A2%E1%86%A8%E1%84%8E%E1%85%AE%E1%86%AF%E1%84%85%E1%85%A7%E1%86%A8.png](attachment:5%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%8C%E1%85%A1%E1%86%AB%E1%84%8B%E1%85%A2%E1%86%A8%E1%84%8E%E1%85%AE%E1%86%AF%E1%84%85%E1%85%A7%E1%86%A8.png)
#
# ---

# %% [markdown]
# ### [6번 문제 : coinbase]
# ---
# * 변경 전
# ![6%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%80%E1%85%A7%E1%86%BC%E1%84%8C%E1%85%A5%E1%86%AB.png](attachment:6%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%80%E1%85%A7%E1%86%BC%E1%84%8C%E1%85%A5%E1%86%AB.png)
# ---

# %% [markdown]
# * 변경
# ![6%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%80%E1%85%A7%E1%86%BC.png](attachment:6%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%80%E1%85%A7%E1%86%BC.png)
# -----

# %% [markdown]
# * 변경 후
# ![6%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%80%E1%85%A7%E1%86%BC%E1%84%92%E1%85%AE.png](attachment:6%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%80%E1%85%A7%E1%86%BC%E1%84%92%E1%85%AE.png)
# ---

# %% [markdown]
# ### [7번 문제 : 트랙잭션 수]
# ---
# ![7%E1%84%87%E1%85%A5%E1%86%AB_tx.png](attachment:7%E1%84%87%E1%85%A5%E1%86%AB_tx.png)
# ---
# * 현재 대기중인 거래가 없음
#
# ---

# %% [markdown]
# ### [8번 문제 : 현재의 블록 번호]
# ---
# ![8%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%8E%E1%85%AC%E1%84%8C%E1%85%A9%E1%86%BC%E1%84%87%E1%85%B3%E1%86%AF%E1%84%85%E1%85%A9%E1%86%A8.png](attachment:8%E1%84%87%E1%85%A5%E1%86%AB_%E1%84%8E%E1%85%AC%E1%84%8C%E1%85%A9%E1%86%BC%E1%84%87%E1%85%B3%E1%86%AF%E1%84%85%E1%85%A9%E1%86%A8.png)
#
# ---
# * [1번]에서 확인한 블록의 수와 동일하다. 실습과정에서 ㄷ블록체인의 단순 조회는 transaction이 발생하지 않는다. 따라서 블록의 수는 변함이 없다. 블록의 수의 변화가 발생하기 위해서는 거래가 발생되어야 한다.
