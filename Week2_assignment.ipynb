# %% [markdown]
# # 휴먼지능정보공학과 201810756 김대환
# ## 블록체인프로그래밍 2주차 과제

# %% [markdown]
# #### [1번 : Code/학번/' 디렉토리]
# ![1_work_directory.png](attachment:1_work_directory.png)

# %% [markdown]
# #### [2번 : 'solc --version']
# ![2_'solc%20--version'.png](attachment:2_'solc%20--version'.png)

# %% [markdown]
# #### [3번 : 'geth -h']
# ![3_'geth%20-v'.png](attachment:3_'geth%20-v'.png)

# %% [markdown]
# #### [4번. : 'admin.nodeInfo(MainNetwork)]
# ![4_main_network_nodeInfo.png](attachment:4_main_network_nodeInfo.png)

# %% [markdown]
# #### [5번 : 'admin.nodeInfo(TestNetwork)]
# ![5_test_network_nodeInfo.png](attachment:5_test_network_nodeInfo.png)
#
# * 강의 자료와는 달리 **chainID : 5** (강의자료 속 chainID:3)

# %% [markdown]
# #### [6번 : 사설망 화면]
# ![6_private_network_log.png](attachment:6_private_network_log.png)

# %% [markdown]
# #### [7번 : 사설망 계정, 충전, 잔액]
# ![7_private_account_miner_getBalance.png](attachment:7_private_account_miner_getBalance.png)

# %% [markdown]
# #### [Discussion]
# 접근 방식으로 rpc(Remote Procedure Call) 방식을 사용하였는데
# 강의 자료와는 달리
# ```python
# geth -h
# ```
# 로 확인하였을 때, rpc 명령어가 모두 http로 변경됨.
# > ex) --rpccorsdomain="*" -> --http.corsdomain="*"
#
# 이에 맞춰서 모든 명령어 수정 완료
#
# --------
#
# 또한 testnet 접속 시 강의자료와는 달리
# ```python
# --testnet
# ```
# 명령어가 아닌
# ```python
# --goerli
# ```
# 명령어 사용 (도움말에 그렇게 적혀있음)
#
# --------
#
# [용어사용에 대한 이해]
# 강의 전반에 걸쳐 종종 활용되는 **.bat** 파일은 배치파일로 윈도우에서는 .bat 확장자를 사용하지만
# 맥과 리눅스 환경에서는 쉘 스크립트로 **.sh** 확장자를 사용함.
# terminal 실행:
# ```python
# sh _파일명.sh
# ```
